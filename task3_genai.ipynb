# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
# Out:
# True

# %%
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
openrouter_client = OpenAI(
    api_key = OPENROUTER_API_KEY,
    base_url = "https://openrouter.ai/api/v1"
)

# %%
messages = [{"role":"system", "content":"you are a conversational botmy name"}]
print("Type START to begin chatting with AI bot, type STOP to end the chat.")
while True:
    user_input = input("Enter your text here: ")
    messages.append(
        {"role":"user", "content":user_input}
    )
    if user_input == "STOP":
        print("Your chat has been ended")
        break
    response = openrouter_client.responses.create(
        model = "inclusionai/ling-3.0-flash-fin:free",
        input = messages,
        tools = [
            {"type":"web_search"}
        ]
    
    )
    messages.append(
        {"role":"assistant", "content":response.output_text}
    )
    print(response.output_text)
# Out:
# Type START to begin chatting with AI bot, type STOP to end the chat.
# Enter your text here:  hi
# Hi there! 👋 How can I help you today?
# Enter your text here:  my name is Aminakhatun Bakriyeva
# Enter your text here:  can you search who am I on web?
